# %%
# Import PyTorch library (used mainly for deep learning & GPU handling)
import torch

# Import TensorFlow library (deep learning framework)
import tensorflow as tf

# Import Pandas for data manipulation (CSV, tables)
import pandas as pd

# Import NumPy for numerical computations
import numpy as np

# Import OpenCV for image processing tasks
import cv2

# Import Google Colab drive module to access Google Drive
from google.colab import drive


# ---------------- GPU CHECK ----------------

# Check whether GPU is available for PyTorch
print("GPU available:", torch.cuda.is_available())

# Print number of GPUs available
print("GPU count:", torch.cuda.device_count())

# If GPU is available, print the GPU name
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))


# ---------------- GOOGLE DRIVE MOUNT ----------------

# Mount Google Drive to access large datasets stored in Drive
drive.mount('/content/drive')
# Out:
# GPU available: True
# GPU count: 1
# GPU name: Tesla T4
# Mounted at /content/drive

# %%
# ---------------- INSTALL REQUIRED LIBRARIES ----------------
# Install PyTorch and related libraries with CUDA support (for GPU acceleration)
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# Install TensorFlow (deep learning framework)
# !pip install tensorflow

# Install core data science libraries
# !pip install pandas numpy scikit-learn

# Install OpenCV (headless version) for image processing tasks
# !pip install opencv-python-headless  # used for reading and processing images

# Install Librosa for audio signal processing
# !pip install librosa                # used for audio feature extraction

# Install Hugging Face Transformers for NLP tasks (BERT, GPT, etc.)
# !pip install transformers           # used for NLP and language models


# ---------------- GOOGLE DRIVE MOUNT (COLAB ONLY) ----------------
# Import Google Colab drive module
from google.colab import drive

# Mount Google Drive to access large datasets stored in Drive
drive.mount('/content/drive')


# ---------------- GPU AVAILABILITY CHECK ----------------
# Import PyTorch to check GPU support
import torch

# Check whether GPU is available
print("GPU available:", torch.cuda.is_available())

# If GPU is available, display the GPU name
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# GPU available: True
# GPU name: Tesla T4

# %% [markdown]
# **TASK**
# **Explore different Deep Learning Packages and Install them**

# %%
# !pip install caffe

# %%
# !pip install monai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 48.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# **LOADING FILES IN DIFFERENT FORMATS**

# %%
import pandas as pd

# Load TSV (tab-separated) file
df = pd.read_csv("/content/drive/MyDrive/Sem6/Neural_Network_and_Deep_Learning/Exp1/dataset.tsv", sep='\t')

# %%
df
# Out:
#       en  original  ?  \
# 0     en  original  ?
# 1     en  original  ?
# 2     en  original  ?
# 3     en  original  ?
# 4     en  original  ?
# ...   ..       ... ..
# 3955  pt  original  ?
# 3956  pt  original  ?
# 3957  pt  original  ?
# 3958  pt  original  ?
# 3959  pt  original  ?
#
#      The city councilmen refused the demonstrators a permit because they feared violence.  \
# 0     The city councilmen refused the demonstrators ...
# 1     The trophy doesn't fit into the brown suitcase...
# 2     The trophy doesn't fit into the brown suitcase...
# 3     Joan made sure to thank Susan for all the help...
# 4     Joan made sure to thank Susan for all the help...
# ...                                                 ...
# 3955  Aline procurou por sua amiga Flavia na multidã...
# 3956  Durante um jogo de pega-pega, Eduardo persegui...
# 3957  Durante um jogo de pega-pega, Eduardo fugiu do...
# 3958  Na competição Loebner os juízes não conseguiam...
# ...

# %% [markdown]
# Task
# # Load TSV (tab‑separated)
# df = pd.read_csv("/content/drive/MyDrive/data/train.tsv", sep="\t")
#
# # Load Excel (XLS/XLSX)
# df = pd.read_excel("/content/drive/MyDrive/data/train.xlsx", sheet_name="Sheet1")

# %%
# Load regular JSON file
df = pd.read_json("/content/drive/MyDrive/Sem6/Neural_Network_and_Deep_Learning/Exp1/premier-league-points-table.json")

# %%
df
# Out:
#        season                                              table
# 0   1992/1993  [{'position': '1', 'team': 'Manchester United'...
# 1   1993/1994  [{'position': '1', 'team': 'Manchester United'...
# 2   1994/1995  [{'position': '1', 'team': 'Blackburn Rovers',...
# 3   1995/1996  [{'position': '1', 'team': 'Manchester United'...
# 4   1996/1997  [{'position': '1', 'team': 'Manchester United'...
# 5   1997/1998  [{'position': '1', 'team': 'Arsenal', 'played'...
# 6   1998/1999  [{'position': '1', 'team': 'Manchester United'...
# 7   1999/2000  [{'position': '1', 'team': 'Manchester United'...
# 8   2000/2001  [{'position': '1', 'team': 'Manchester United'...
# 9   2001/2002  [{'position': '1', 'team': 'Arsenal', 'played'...
# 10  2002/2003  [{'position': '1', 'team': 'Manchester United'...
# 11  2003/2004  [{'position': '1', 'team': 'Arsenal', 'played'...
# 12  2004/2005  [{'position': '1', 'team': 'Chelsea', 'played'...
# ...

# %%
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df = pd.read_csv(url)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.datasets import load_iris
X, y = load_iris(return_X_y=True)

# %%
from tensorflow.keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# **TASK**
# Upload built-in dataset

# %%
# Import OpenCV library (used for image processing; not directly used here)
import cv2

# Import PIL to load images in Python
from PIL import Image

# Import PyTorch library
import torch

# Import matplotlib for displaying images
import matplotlib.pyplot as plt

# Import torchvision transforms for image preprocessing
from torchvision import transforms


# -------------------------------
# STEP 1: Load the image using PIL
# -------------------------------

# Open the image file from the given path
pil_img = Image.open("/content/drive/MyDrive/Sem6/Neural_Network_and_Deep_Learning/Exp1/dragon.jpg")


# -------------------------------------
# STEP 2: Define image transformations
# -------------------------------------

# Resize image to 224x224 (standard input size for CNNs)
# Convert image to PyTorch tensor (values scaled to [0, 1])
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])


# -------------------------------------
# STEP 3: Apply transforms to the image
# -------------------------------------

# Apply preprocessing and convert PIL image to tensor
# Shape becomes: [3, 224, 224] → (Channels, Height, Width)
img_tensor = transform(pil_img)

# Add batch dimension required by deep learning models
# Final shape: [1, 3, 224, 224]
img_tensor = img_tensor.unsqueeze(0)


# -------------------------------------
# STEP 4: Visualize the image
# -------------------------------------

# Create a figure with fixed size
plt.figure(figsize=(6, 6))

# Remove batch dimension: [3, 224, 224]
# Change tensor order from (C, H, W) to (H, W, C)
# Convert tensor to NumPy array for matplotlib
img_np = img_tensor[0].permute(1, 2, 0).numpy()

# Display the image
plt.imshow(img_np)

# Hide axis values for cleaner visualization
plt.axis("off")

# Set title for the image
plt.title("Loaded image as tensor")

# Show the image
plt.show()

# %%
# Import librosa library for audio processing
import librosa

# -------------------------------------
# STEP 1: Load the audio file
# -------------------------------------

# Load the audio file from the given path
# audio → 1D NumPy array containing the audio signal (amplitude values)
# sr → sample rate of the audio (samples per second)
# sr=None ensures the original sample rate is preserved
audio, sr = librosa.load("/content/drive/MyDrive/Sem6/Neural_Network_and_Deep_Learning/Exp1/diamond_tunes.mp3", sr=None)


# -------------------------------------
# STEP 2: Display basic audio information
# -------------------------------------

# Print the sample rate of the audio file
print("Sample rate:", sr)

# Print the shape of the audio array
# Length indicates number of audio samples
print("Audio shape:", audio.shape)
# Out:
# Sample rate: 44100
# Audio shape: (461952,)

# %%
# Load entire text file
with open("/content/drive/MyDrive/Sem6/Neural_Network_and_Deep_Learning/Exp1/sample.txt", "r", encoding="utf-8") as f:
    text = f.read()

# Load line‑by‑line
with open("/content/drive/MyDrive/Sem6/Neural_Network_and_Deep_Learning/Exp1/sample.txt", "r", encoding="utf-8") as f:
    lines = f.readlines()

# %%
text
# Out:
# '"Descend into chaos! Descend! Only with everything in chaos will I get the chance to fish in troubled waters!"\n\n"Dying, he knew not his executor; surviving, he knew not the circumstances."\n\n"And for the mastermind behind all this, the greatest murderer, he would step up to the divine throne over a pile of corpses, only to receive cheers and escape his mortal coils."\n\n"You are still too young. After you experience many things like me, you will understand that compared to drawing your sword and sacrificing your blood in a zealous fervor,\n ensuring humiliation and helplessness, and persisting in the darkness is even more difficult and painful."'

# %%
# -----------------------------------
# SINGLE NEURON: FORWARD PASS ONLY
# Input → Weights → Sum → Activation → Output
# -----------------------------------

import numpy as np

# Step 1: Input values
inputs = np.array([1, 2])     # x1 = 1, x2 = 2

# Step 2: Weights
weights = np.array([0.4, 0.6])  # w1, w2

# Step 3: Bias
bias = 0.2

# Step 4: Weighted sum
weighted_sum = np.dot(inputs, weights) + bias

# Step 5: Activation function (Sigmoid)
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Step 6: Output
output = sigmoid(weighted_sum)

# Step 7: Print each stage
print("Input:", inputs)
print("Weights:", weights)
print("Weighted Sum (z):", weighted_sum)
print("Final Output:", output)
# Out:
# Input: [1 2]
# Weights: [0.4 0.6]
# Weighted Sum (z): 1.8
# Final Output: 0.8581489350995123

# %%
# ----------------------------------------
# BASIC NEURAL NETWORK IMPLEMENTATION
# ----------------------------------------

# Step 1: Import required library
import numpy as np

# Step 2: Define input data (AND logic)
# Each row is one input sample
X = np.array([[0, 0],
              [0, 1],
              [1, 0],
              [1, 1]])

# Step 3: Define expected output
# AND logic output
y = np.array([[0],
              [0],
              [0],
              [1]])

# Step 4: Initialize weights and bias randomly
# 2 input neurons -> 1 output neuron
weights = np.random.rand(2, 1)
bias = np.random.rand(1)

# Step 5: Define activation function (Sigmoid)
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Step 6: Define derivative of sigmoid
def sigmoid_derivative(x):
    return x * (1 - x)

# Step 7: Training parameters
learning_rate = 0.1
epochs = 10000

# Step 8: Training the neural network
for epoch in range(epochs):

    # Forward propagation
    z = np.dot(X, weights) + bias        # Weighted sum
    output = sigmoid(z)                  # Activation output

    # Calculate error
    error = y - output

    # Backpropagation
    d_output = error * sigmoid_derivative(output)

    # Update weights and bias
    weights += learning_rate * np.dot(X.T, d_output)
    bias += learning_rate * np.sum(d_output)

# Step 9: Display final results
print("Final Weights:\n", weights)
print("Final Bias:\n", bias)

# Step 10: Test the network
print("\nPredicted Output after Training:")
print(output)
# Out:
# Final Weights:
#  [[5.47827062]
#  [5.47827061]]
# Final Bias:
#  [-8.31010317]
#
# Predicted Output after Training:
# [[2.46001223e-04]
#  [5.56310977e-02]
#  [5.56310978e-02]
#  [9.33787460e-01]]

# %%
from IPython.display import HTML
from base64 import b64encode

def show_video(video_path):
    video_file = open(video_path, "r+b").read()
    video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
    return HTML(f"""<video width={600} controls><source src="{video_url}" type="video/mp4"></video>""")

# Example usage:
show_video('/content/drive/MyDrive/Sem6/Neural_Network_and_Deep_Learning/Exp1/video.mp4')
# Out:
# <video width=600 controls><source src="data:video/mp4;base64,..." type="video/mp4"></video>
